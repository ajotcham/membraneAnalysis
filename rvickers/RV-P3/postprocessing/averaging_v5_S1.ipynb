# %%
import re
def sorted_alphanumeric(data):
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [ convert(c) for c in re.split('([0-9]+)', key) ] 
    return sorted(data, key=alphanum_key)

# %%
import numpy as np 
import pandas as pd
import os
import gc
import gzip
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
x_min = 0
x_max = 97.7228
y_min = 0
y_max = 166.129
# x_min = 0
# x_max = 119.544
# y_min = 0
# y_max = 138.038
x_len = x_max - x_min
y_len = y_max - y_min


ang3_to_cm3 = (1e8)**3
avo_num = 6.0221409e+23

# Set parent directory containing allsimulations to be analyzed 

gap_size = '10'
pressure_diff = '200'

parentDir = "../pa_gap/pa_gap"+gap_size+"_nve"+pressure_diff+"/"
allWaterArr = []
# loop over all simulation folders
for simDir in sorted_alphanumeric(os.listdir(parentDir)):
    waterArr = []
    # data is expected to be in a folder titled pressure
    dataDir = parentDir+simDir
    for step in sorted_alphanumeric(os.listdir(dataDir)):
        waterArr.append(dataDir+"/"+step)
    if waterArr:
        allWaterArr.append(waterArr)
    else:
        print("No water array created for: " + dataDir)
print(allWaterArr)
# Out:
# [['../pa_gap/pa_gap10_nve200/pressure/pressuredata.1610000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1615000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1620000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1625000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1630000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1635000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1640000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1645000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1650000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1655000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1660000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1665000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1670000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1675000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1680000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1685000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1690000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1695000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1700000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1705000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1710000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1715000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1720000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1725000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1730000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1735000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1740000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1745000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1750000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1755000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1760000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1765000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1770000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1775000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1780000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1785000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1790000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1795000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1800000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1805000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1810000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1815000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1820000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1825000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1830000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1835000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1840000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1845000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1850000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1855000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1860000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1865000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1870000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1875000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1880000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1885000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1890000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1895000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1900000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1905000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1910000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1915000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1920000.gz', '../pa_gap/pa_gap10_nve200/pressure/pressuredata.1925000.gz', '../pa_gap/pa_gap10_nve200/pre ...

# %%
i=0
min_atom_positions = []
max_atom_positions = []
# loop through arrays of file names containing data to be analyzed
for waterArr in allWaterArr:
    if i != 0:
        i+=1
        continue  
    timesteps = []
    waterdfs = []
    print(waterArr[0])  
    for waterFile in waterArr:
        print(waterFile)
        with gzip.open(waterFile) as f:
            f.readline().rstrip()
            timestep = f.readline().rstrip().decode("utf-8") 
        timesteps.append(timestep)
        idf = pd.read_csv(waterFile).iloc[7:,:]
        dfCols = idf.iloc[0,].str.split(' ')[0]
        del dfCols[0:2]
        df = idf.iloc[1:,:]['ITEM: TIMESTEP'].str.split(' ', expand=True)
        df.set_axis(dfCols,axis=1,inplace=True)
        df.reset_index(drop=True, inplace=True)
        df = df.apply(pd.to_numeric)
        min_atom_positions.append(df['z'].min())
        max_atom_positions.append(df['z'].max())
#         df = df[df.type.isin([15,16])]
#         df = df[df.vz != 0]
        waterdfs.append(df)
    i+=1
# Out:
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1610000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1610000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1615000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1620000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1625000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1630000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1635000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1640000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1645000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1650000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1655000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1660000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1665000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1670000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1675000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1680000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1685000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1690000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1695000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1700000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1705000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1710000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1715000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1720000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1725000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1730000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1735000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1740000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1745000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1750000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1755000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1760000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1765000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1770000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1775000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1780000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1785000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1790000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1795000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1800000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1805000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1810000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1815000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1820000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1825000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1830000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1835000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1840000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1845000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1850000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1855000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1860000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1865000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1870000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1875000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1880000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1885000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1890000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1895000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1900000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1905000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1910000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1915000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1920000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1925000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1930000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1935000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1940000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1945000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1950000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1955000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1960000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1965000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1970000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1975000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1980000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1985000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1990000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.1995000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2000000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2005000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2010000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2015000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2020000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2025000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2030000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2035000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2040000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2045000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2050000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2055000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2060000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2065000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2070000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2075000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2080000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2085000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2090000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2095000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2100000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2105000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2110000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2115000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2120000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2125000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2130000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2135000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2140000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2145000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2150000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2155000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2160000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2165000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2170000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2175000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2180000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2185000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2190000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2195000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2200000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2205000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2210000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2215000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2220000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2225000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2230000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2235000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2240000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2245000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2250000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2255000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2260000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2265000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2270000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2275000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2280000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2285000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2290000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2295000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2300000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2305000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2310000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2315000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2320000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2325000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2330000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2335000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2340000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2345000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2350000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2355000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2360000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2365000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2370000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2375000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2380000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2385000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2390000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2395000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2400000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2405000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2410000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2415000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2420000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2425000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2430000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2435000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2440000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2445000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2450000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2455000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2460000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2465000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2470000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2475000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2480000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2485000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2490000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2495000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2500000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2505000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2510000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2515000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2520000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2525000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2530000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2535000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2540000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2545000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2550000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2555000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2560000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2565000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2570000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2575000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2580000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2585000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2590000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2595000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2600000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2605000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2610000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2615000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2620000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2625000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2630000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2635000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2640000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2645000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2650000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2655000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2660000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2665000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2670000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2675000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2680000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2685000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2690000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2695000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2700000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2705000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2710000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2715000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2720000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2725000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2730000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2735000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2740000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2745000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2750000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2755000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2760000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2765000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2770000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2775000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2780000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2785000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2790000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2795000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2800000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2805000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2810000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2815000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2820000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2825000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2830000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2835000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2840000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2845000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2850000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2855000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2860000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2865000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2870000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2875000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2880000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2885000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2890000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2895000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2900000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2905000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2910000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2915000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2920000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2925000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2930000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2935000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2940000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2945000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2950000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2955000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2960000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2965000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2970000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2975000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2980000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2985000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2990000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.2995000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3000000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3005000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3010000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3015000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3020000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3025000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3030000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3035000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3040000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3045000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3050000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3055000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3060000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3065000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3070000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3075000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3080000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3085000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3090000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3095000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3100000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3105000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3110000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3115000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3120000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3125000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3130000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3135000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3140000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3145000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3150000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3155000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3160000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3165000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3170000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3175000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3180000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3185000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3190000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3195000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3200000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3205000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3210000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3215000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3220000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3225000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3230000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3235000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3240000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3245000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3250000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3255000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3260000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3265000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3270000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3275000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3280000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3285000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3290000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3295000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3300000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3305000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3310000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3315000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3320000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3325000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3330000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3335000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3340000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3345000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3350000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3355000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3360000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3365000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3370000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3375000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3380000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3385000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3390000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3395000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3400000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3405000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3410000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3415000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3420000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3425000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3430000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3435000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3440000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3445000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3450000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3455000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3460000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3465000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3470000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3475000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3480000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3485000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3490000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3495000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3500000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3505000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3510000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3515000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3520000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3525000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3530000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3535000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3540000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3545000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3550000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3555000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3560000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3565000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3570000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3575000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3580000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3585000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3590000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3595000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3600000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3605000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3610000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3615000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3620000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3625000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3630000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3635000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3640000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3645000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3650000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3655000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3660000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3665000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3670000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3675000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3680000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3685000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3690000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3695000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3700000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3705000.gz
# ../pa_gap/pa_gap10_nve200/pressure/pressuredata.3710000.gz
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22520/828269568.py in <module>
#      19         dfCols = idf.iloc[0,].str.split(' ')[0]
#      20         del dfCols[0:2]
# ---> 21         df = idf.iloc[1:,:]['ITEM: TIMESTEP'].str.split(' ', expand=True)
#      22         df.set_axis(dfCols,axis=1,inplace=True)
#      23         df.reset_index(drop=True, inplace=True)
#
# ~\miniconda3\lib\site-packages\pandas\core\strings\accessor.py in wrapper(self, *args, **kwargs)
#     114                 )
#     115                 raise TypeError(msg)
# --> 116             return func(self, *args, **kwargs)
#     117
#     118         wrapper.__name__ = func_name
#
# ~\miniconda3\lib\site-packages\pandas\core\strings\accessor.py in split(self, pat, n, expand)
#     787     @forbid_nonstring_types(["bytes"])
#     788     def split(self, pat=None, n=-1, expand=False):
# --> 789         result = self._data.array._str_split(pat, n, expand)
#     790         return self._wrap_result(result, returns_string=expand, expand=expand)
#     791
#
# ~\miniconda3\lib\site-packages\pandas\core\strings\object_array.py in _str_split(self, pat, n, expand)
#     320                 regex = re.compile(pat)
#     321                 f = lambda x: regex.split(x, maxsplit=n)
# --> 322         return self._str_map(f, dtype=object)
#     323
#     324     def _str_rsplit(self, pat=None, n=-1):
#
# ~\miniconda3\lib\site-packages\pandas\core\strings\object_array.py in _str_map(self, f, na_value, dtype, convert)
#      67         map_convert = convert and not np.all(mask)
#      68         try:
# ---> 69             result = lib.map_infer_mask(arr, f, mask.view(np.uint8), map_convert)
#      70         except (TypeError, AttributeError) as e:
#      71             # Reraise the exception if callable `f` got wrong number of args.
#
# ~\miniconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer_mask()
#
# ~\miniconda3\lib\site-packages\pandas\core\strings\object_array.py in <lambda>(x)
#     314                 if n is None or n == 0:
#     315                     n = -1
# --> 316                 f = lambda x: x.split(pat, n)
#     317             else:
#     318                 if n is None or n == -1:
#
# KeyboardInterrupt:

# %%
pressureSeries = []
densitySeries = []
countSeries = []
vxSeries = []
vySeries = []
vzSeries = []

gapPressureSeries = []
gapDensitySeries = []
gapCountSeries = []
gapvxSeries = []
gapvySeries = []
gapvzSeries = []

## gap10
# gap_min = 21
# gap_max = 32

## gap46
gap_min = 60
gap_max = 106

gap_len = gap_max - gap_min
nGapBins = int((gap_len * 0.5) + 1)
gapBinSize = gap_len/nGapBins

z_min = -128.921
z_max = 571.635
z_len = z_max - z_min

nBins = int((z_len * 0.5) + 1)
bin_size = z_len/nBins

min_timestep = 0
max_timestep = 800000000

inlet_z = 105
outlet_z = 280

feedPressures = []
gapPressures = []
permPressures = []

feedCount = []
gapCount = []
permCount = []

feedvxs = []
gapvxs = []
permvxs = []

feedvys = []
gapvys = []
permvys = []

feedvzs = []
gapvzs = []
permvzs = []

i=0
for df in waterdfs:
    if ((int(timesteps[i]) < min_timestep) or (int(timesteps[i]) > max_timestep)):
        i+=1
        continue
    dfMol = pd.DataFrame()

    df['xmass'] = df['mass'] * df['x']
    df['ymass'] = df['mass'] * df['y']
    df['zmass'] = df['mass'] * df['z']
    
    df['vxmass'] = df['mass'] * df['vx']
    df['vymass'] = df['mass'] * df['vy']
    df['vzmass'] = df['mass'] * df['vz']

    # create per molecule dataframe to analyze at finer scale
    # atoms of a molecule are expected to be consecutive

    dfMol['mass'] = df['mass'].groupby(df.index // 3).sum()
    dfMol['xmass'] = df['xmass'].groupby(df.index // 3).sum()
    dfMol['ymass'] = df['ymass'].groupby(df.index // 3).sum()
    dfMol['zmass'] = df['zmass'].groupby(df.index // 3).sum()
    dfMol['vxmass'] = df['vxmass'].groupby(df.index // 3).sum()
    dfMol['vymass'] = df['vymass'].groupby(df.index // 3).sum()
    dfMol['vzmass'] = df['vzmass'].groupby(df.index // 3).sum()
    dfMol['x'] = dfMol['xmass'] / dfMol['mass']
    dfMol['y'] = dfMol['ymass'] / dfMol['mass']
    dfMol['z'] = dfMol['zmass'] / dfMol['mass']
    dfMol['vx'] = dfMol['vxmass'] / dfMol['mass']
    dfMol['vy'] = dfMol['vymass'] / dfMol['mass']
    dfMol['vz'] = dfMol['vzmass'] / dfMol['mass']
    dfMol['stressvol'] = df['v_peratompress'].groupby(df.index // 3).sum()
    dfMol['vol'] = df['c_peratomvol[1]'].groupby(df.index // 3).sum()
    dfMol['press'] = dfMol['stressvol'] / (-3 * dfMol['vol'])
    dfMol['density'] = (dfMol['mass'] / (x_len * y_len * z_len/nBins)) * ang3_to_cm3 / avo_num
    dfMol['pressbin'] = (dfMol['stressvol'] / (-3 * x_len * y_len * z_len/nBins))
    dfMol['bin'] = pd.cut(dfMol['z'], np.linspace(z_min,z_max,nBins),labels=False)*bin_size + (z_min)
    dfMol['ybin'] = pd.cut(dfMol['y'].loc[(dfMol['z'] > inlet_z) & (dfMol['z'] < outlet_z)], np.linspace(gap_min,gap_max,nGapBins), labels=False) * gapBinSize + gap_min
#     stepDF_mean = dfMol.loc[(max_atom_positions[i]-dfMol['z'] > 5) & (dfMol['z']-min_atom_positions[i] > 5)].groupby(['bin'], dropna=True).mean()
#     stepDF_sum = dfMol.loc[(max_atom_positions[i]-dfMol['z'] > 5) & (dfMol['z']-min_atom_positions[i] > 5)].groupby(['bin'], dropna=True).sum()
    stepDF_mean = dfMol.groupby(['bin'], dropna=True).mean()
    stepDF_sum = dfMol.groupby(['bin'], dropna=True).sum()
    stepDF_sum['bin_count'] = dfMol.groupby(['bin'], dropna=True)['bin'].count() 
    gapDF_mean = dfMol.groupby(['ybin'], dropna=True).mean()
    gapDF_sum = dfMol.groupby(['ybin'], dropna=True).sum()
    gapDF_sum['ybin_count'] = dfMol.groupby(['ybin'], dropna=True)['ybin'].count()
    
    feedPressures.append(dfMol['stressvol'].loc[(dfMol['z'] < inlet_z) & (dfMol['z']-min_atom_positions[i] > 5)].sum() / (-3 * dfMol['vol'].loc[(dfMol['z'] < inlet_z) & (dfMol['z']-min_atom_positions[i] > 5)].sum()))
    gapPressures.append(dfMol['stressvol'].loc[(dfMol['z'] < outlet_z) & (dfMol['z'] > inlet_z)].sum() / (-3 * dfMol['vol'].loc[(dfMol['z'] < outlet_z) & (dfMol['z'] > inlet_z)].sum()))
    permPressures.append(dfMol['stressvol'].loc[(dfMol['z'] > outlet_z) & (max_atom_positions[i]-dfMol['z'] > 5)].sum() / (-3 * dfMol['vol'].loc[(dfMol['z'] > outlet_z) & (max_atom_positions[i]-dfMol['z'] > 5)].sum()))
#     feedPressures.append(dfMol['stressvol'].loc[(dfMol['z'] < -50)].sum() / (-3 * x_len * y_len * (-50-min_atom_positions[i])))
#     permPressures.append(dfMol['stressvol'].loc[(dfMol['z'] > 50)].sum() / (-3 * x_len * y_len * (max_atom_positions[i]-50)))
    
    feedCount.append(dfMol['bin'].loc[(dfMol['z'] < inlet_z)].count())
    gapCount.append(dfMol['bin'].loc[(dfMol['z'] < outlet_z) & (dfMol['z'] > inlet_z)].count())
    permCount.append(dfMol['bin'].loc[(dfMol['z'] > outlet_z)].count())
    
    feedvxs.append(dfMol['vx'].loc[(dfMol['z'] < inlet_z) & (dfMol['z']-min_atom_positions[i] > 5)].mean())
    gapvxs.append(dfMol['vx'].loc[(dfMol['z'] < outlet_z) & (dfMol['z'] > inlet_z)].mean())
    permvxs.append(dfMol['vx'].loc[(dfMol['z'] > outlet_z) & (max_atom_positions[i]-dfMol['z'] > 5)].mean())

    feedvys.append(dfMol['vy'].loc[(dfMol['z'] < inlet_z) & (dfMol['z']-min_atom_positions[i] > 5)].mean())
    gapvys.append(dfMol['vy'].loc[(dfMol['z'] < outlet_z) & (dfMol['z'] > inlet_z)].mean())
    permvys.append(dfMol['vy'].loc[(dfMol['z'] > outlet_z) & (max_atom_positions[i]-dfMol['z'] > 5)].mean())

    feedvzs.append(dfMol['vz'].loc[(dfMol['z'] < inlet_z) & (dfMol['z']-min_atom_positions[i] > 5)].mean())
    gapvzs.append(dfMol['vz'].loc[(dfMol['z'] < outlet_z) & (dfMol['z'] > inlet_z)].mean())
    permvzs.append(dfMol['vz'].loc[(dfMol['z'] > outlet_z) & (max_atom_positions[i]-dfMol['z'] > 5)].mean())

    vxSeries.append(stepDF_mean['vx'].rename(timesteps[i], axis=1))
    vySeries.append(stepDF_mean['vy'].rename(timesteps[i], axis=1))
    vzSeries.append(stepDF_mean['vz'].rename(timesteps[i], axis=1))
    
    pressureSeries.append(stepDF_sum['stressvol'].rename(timesteps[i], axis=1)/(-3*stepDF_sum['vol'].rename(timesteps[i], axis=1)))
    densitySeries.append((stepDF_sum['mass'].rename(timesteps[i], axis=1)/(stepDF_sum['vol'].rename(timesteps[i], axis=1)))* ang3_to_cm3 / avo_num)
    countSeries.append(stepDF_sum['bin_count'].rename(timesteps[i], axis=1))
    
    gapCountSeries.append(gapDF_sum['ybin_count'].rename(timesteps[i], axis=1))
    gapPressureSeries.append(gapDF_sum['stressvol'].rename(timesteps[i], axis=1)/(-3*gapDF_sum['vol'].rename(timesteps[i], axis=1)))
    gapDensitySeries.append((gapDF_sum['mass'].rename(timesteps[i], axis=1)/(gapDF_sum['vol'].rename(timesteps[i], axis=1)))* ang3_to_cm3 / avo_num)
    gapvxSeries.append(gapDF_mean['vx'].rename(timesteps[i], axis=1))
    gapvySeries.append(gapDF_mean['vy'].rename(timesteps[i], axis=1))
    gapvzSeries.append(gapDF_mean['vz'].rename(timesteps[i], axis=1))
    i += 1

pressureSeriesDF = pd.concat(pressureSeries, axis=1, ignore_index=False)
densitySeriesDF = pd.concat(densitySeries,axis=1, ignore_index=False)
countSeriesDF = pd.concat(countSeries, axis=1, ignore_index=False)
vxSeriesDF = pd.concat(vxSeries, axis=1, ignore_index=False)
vySeriesDF = pd.concat(vySeries, axis=1, ignore_index=False)                    
vzSeriesDF = pd.concat(vzSeries, axis=1, ignore_index=False)

gapCountSeriesDF = pd.concat(gapCountSeries, axis=1, ignore_index=False)
gapPressureSeriesDF = pd.concat(gapPressureSeries, axis=1, ignore_index=False)
gapDensitySeriesDF = pd.concat(gapDensitySeries,axis=1, ignore_index=False)
gapvxSeriesDF = pd.concat(gapvxSeries, axis=1, ignore_index=False)
gapvySeriesDF = pd.concat(gapvySeries, axis=1, ignore_index=False)                    
gapvzSeriesDF = pd.concat(gapvzSeries, axis=1, ignore_index=False)
                       
                       
AVGpressureSeriesDF = pd.DataFrame()
AVGdensitySeriesDF = pd.DataFrame()
AVGvxSeriesDF = pd.DataFrame()
AVGvySeriesDF = pd.DataFrame()
AVGvzSeriesDF = pd.DataFrame()
AVGcountSeriesDF = pd.DataFrame()

AVGgapPressureSeriesDF = pd.DataFrame()
AVGgapDensitySeriesDF = pd.DataFrame()
AVGgapCountSeriesDF = pd.DataFrame()

AVGgapvxSeriesDF = pd.DataFrame()
AVGgapvySeriesDF = pd.DataFrame()
AVGgapvzSeriesDF = pd.DataFrame()            

AVGpressureSeriesDF['mean'] = pressureSeriesDF.mean(axis=1)
AVGpressureSeriesDF['stdev'] = pressureSeriesDF.std(axis=1)

AVGdensitySeriesDF['mean'] = densitySeriesDF.mean(axis=1)
AVGdensitySeriesDF['stdev'] = densitySeriesDF.std(axis=1)

AVGcountSeriesDF['mean'] = countSeriesDF.mean(axis=1)
AVGcountSeriesDF['stdev'] = countSeriesDF.std(axis=1)

AVGvxSeriesDF['mean'] = vxSeriesDF.mean(axis=1)
AVGvxSeriesDF['stdev'] = vxSeriesDF.std(axis=1)
AVGvySeriesDF['mean'] = vySeriesDF.mean(axis=1)
AVGvySeriesDF['stdev'] = vySeriesDF.std(axis=1)
AVGvzSeriesDF['mean'] = vzSeriesDF.mean(axis=1)
AVGvzSeriesDF['stdev'] = vzSeriesDF.std(axis=1)
                       
AVGgapCountSeriesDF['mean'] = gapCountSeriesDF.mean(axis=1)
AVGgapCountSeriesDF['stdev'] = gapCountSeriesDF.std(axis=1)
AVGgapPressureSeriesDF['mean'] = gapPressureSeriesDF.mean(axis=1)
AVGgapPressureSeriesDF['stdev'] = gapPressureSeriesDF.std(axis=1)
AVGgapDensitySeriesDF['mean'] = gapDensitySeriesDF.mean(axis=1)
AVGgapDensitySeriesDF['stdev'] = gapDensitySeriesDF.std(axis=1)
                       
AVGgapvxSeriesDF['mean'] = gapvxSeriesDF.mean(axis=1)
AVGgapvxSeriesDF['stdev'] = gapvxSeriesDF.std(axis=1)
AVGgapvySeriesDF['mean'] = gapvySeriesDF.mean(axis=1)
AVGgapvySeriesDF['stdev'] = gapvySeriesDF.std(axis=1)
AVGgapvzSeriesDF['mean'] = gapvzSeriesDF.mean(axis=1)
AVGgapvzSeriesDF['stdev'] = gapvzSeriesDF.std(axis=1)

pressureSeriesDF.index.names = ['Distance in z (Å)']
AVGpressureSeriesDF.index.names = ['Distance in z (Å)']

densitySeriesDF.index.names = ['Distance in z (Å)']
AVGdensitySeriesDF.index.names = ['Distance in z (Å)']
                       
vxSeriesDF.index.names = ['Distance in z (Å)']
AVGvxSeriesDF.index.names = ['Distance in z (Å)']                      
vySeriesDF.index.names = ['Distance in z (Å)']
AVGvySeriesDF.index.names = ['Distance in z (Å)']        
vzSeriesDF.index.names = ['Distance in z (Å)']
AVGvzSeriesDF.index.names = ['Distance in z (Å)']                      

gapCountSeriesDF.index.names = ['Distance in y (Å)']
AVGgapCountSeriesDF.index.names = ['Distance in y (Å)']
gapPressureSeriesDF.index.names = ['Distance in y (Å)']
AVGgapPressureSeriesDF.index.names = ['Distance in y (Å)']
gapDensitySeriesDF.index.names = ['Distance in y (Å)']
AVGgapDensitySeriesDF.index.names = ['Distance in y (Å)']

gapvxSeriesDF.index.names = ['Distance in y (Å)']
AVGgapvxSeriesDF.index.names = ['Distance in y (Å)']     
gapvySeriesDF.index.names = ['Distance in y (Å)']
AVGgapvySeriesDF.index.names = ['Distance in y (Å)']    
gapvzSeriesDF.index.names = ['Distance in y (Å)']
AVGgapvzSeriesDF.index.names = ['Distance in y (Å)']    
                       
                       
# pressureSeriesDF.set_index(pressureSeriesDF.index*bin_size,inplace=True)
# AVGpressureSeriesDF.set_index(AVGpressureSeriesDF.index*bin_size,inplace=True)
# densitySeriesDF.set_index(densitySeriesDF.index*bin_size,inplace=True)
# AVGdensitySeriesDF.set_index(AVGdensitySeriesDF.index*bin_size,inplace=True)

# countSeriesDF.set_index(countSeriesDF.index*bin_size,inplace=True)
# AVGcountSeriesDF.set_index(AVGcountSeriesDF.index*bin_size,inplace=True)
                       
# vxSeriesDF.set_index(vxSeriesDF.index*bin_size,inplace=True)
# AVGvxSeriesDF.set_index(AVGvxSeriesDF.index*bin_size,inplace=True)
# vySeriesDF.set_index(vySeriesDF.index*bin_size,inplace=True)
# AVGvySeriesDF.set_index(AVGvySeriesDF.index*bin_size,inplace=True)
# vzSeriesDF.set_index(vzSeriesDF.index*bin_size,inplace=True)
# AVGvzSeriesDF.set_index(AVGvzSeriesDF.index*bin_size,inplace=True)

# %%
pressureSeriesDF.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_pressure.csv')
AVGpressureSeriesDF.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_pressure_avg.csv')
pressureSeriesDF.plot(alpha=0.1, legend=False, ylabel='Pressure of molecules within bin (ATM)')
# plt.savefig('./plots/pressure_all_ts.jpg',bbox_inches='tight')
AVGpressureSeriesDF.plot(yerr='stdev',legend=False, ylabel='Pressure of molecules within bin (ATM)', ylim = (-1500,2500))
plt.savefig('./plots/pagap'+gap_size+'_nve'+pressure_diff+'_pressure_avg.jpg',bbox_inches='tight')


print(pressureSeriesDF.mean().mean())
print(pressureSeriesDF.mean().std())
print(AVGpressureSeriesDF.mean())
# Out:
# 123.1872475457649
# 173.8804071444702
# mean     207.879341
# stdev    786.987475
# dtype: float64

# %%
densitySeriesDF.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_density.csv')
AVGdensitySeriesDF.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_density_avg.csv')
densitySeriesDF.plot(alpha=0.1, legend=False, ylabel='Density of molecules within bin (g/cm$^3$)')
# plt.savefig('./plots/pressure_all_ts.jpg',bbox_inches='tight')
AVGdensitySeriesDF.plot(yerr='stdev',legend=False, ylabel='Density of molecules within bin (g/cm$^3$)')
plt.savefig('./plots/pagap'+gap_size+'_nve'+pressure_diff+'_density_avg.jpg',bbox_inches='tight')


print(densitySeriesDF.mean().mean())
print(densitySeriesDF.mean().std())
print(AVGdensitySeriesDF.mean())
# Out:
# 0.9900840267435461
# 0.005199401831910464
# mean     0.977393
# stdev    0.014626
# dtype: float64

# %%
vzSeriesDF.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_vz.csv')
AVGvzSeriesDF.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_vz_avg.csv')
vzSeriesDF.plot(alpha=0.1, legend=False, ylabel='Velocity of molecules in direction of flow (Å/fs)')
# plt.savefig('./plots/pressure_all_ts.jpg',bbox_inches='tight')
AVGvzSeriesDF.plot(yerr='stdev',legend=False, ylabel='Velocity of molecules in direction of flow (Å/fs)')
plt.savefig('./plots/pagap'+gap_size+'_nve'+pressure_diff+'_vz_avg.jpg',bbox_inches='tight')


print(vzSeriesDF.mean().mean())
print(vzSeriesDF.mean().std())
print(AVGvzSeriesDF.mean())
# Out:
# 8.057939895200073e-07
# 2.5887450105368373e-05
# mean     0.000003
# stdev    0.000260
# dtype: float64

# %%
resPressures = pd.DataFrame((feedPressures,gapPressures,permPressures),index=('feed','gap','perm'), columns=timesteps)
resPressures.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_res_pressures.csv')
pfeeds = np.array(feedPressures)
pgaps = np.array(gapPressures)
pperms = np.array(permPressures)

pfeedavg = np.mean(pfeeds)
pfeedstd = np.std(pfeeds)
pgapavg = np.mean(pgaps)
pgapstd = np.std(pgaps)
ppermavg = np.mean(pperms)
ppermstd = np.std(pperms)

print("feed")
print(pfeedavg,pfeedstd)
print("gap")
print(pgapavg,pgapstd)
print("perm")
print(ppermavg,ppermstd)
# Out:
# feed
# 368.58646968649526 207.13459086992628
# gap
# -83.21312187023683 299.04891334719946
# perm
# 77.79095956352391 153.17941804019307

# %%
resVelocities = pd.DataFrame((feedvxs,gapvxs,permvxs,feedvys,gapvys,permvys,feedvzs,gapvzs,permvzs),index=('feedvx','gapvx','permvx','feedvy','gapvy','permvy','feedvz','gapvz','permvz'),columns=timesteps)
resVelocities.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_res_velocties.csv')

vxfeeds = np.array(feedvxs)
vxgaps = np.array(gapvxs)
vxperms = np.array(permvxs)

vxfeedavg = np.mean(vxfeeds)
vxfeedstd = np.std(vxfeeds)
vxgapavg = np.mean(vxgaps)
vxgapstd = np.std(vxgaps)
vxpermavg = np.mean(vxperms)
vxpermstd = np.std(vxperms)

vyfeeds = np.array(feedvys)
vygaps = np.array(gapvys)
vyperms = np.array(permvys)

vyfeedavg = np.mean(vyfeeds)
vyfeedstd = np.std(vyfeeds)
vygapavg = np.mean(vygaps)
vygapstd = np.std(vygaps)
vypermavg = np.mean(vyperms)
vypermstd = np.std(vyperms)

vzfeeds = np.array(feedvzs)
vzgaps = np.array(gapvzs)
vzperms = np.array(permvzs)

vzfeedavg = np.mean(vzfeeds)
vzfeedstd = np.std(vzfeeds)
vzgapavg = np.mean(vzgaps)
vzgapstd = np.std(vzgaps)
vzpermavg = np.mean(vzperms)
vzpermstd = np.std(vzperms)

print("Vx")
print(vxfeedavg,vxfeedstd)
print(vxgapavg,vxgapstd)
print(vxpermavg,vxpermstd)

print("Vy")
print(vyfeedavg,vyfeedstd)
print(vygapavg,vygapstd)
print(vypermavg,vypermstd)

print("Vz")
print(vzfeedavg,vzfeedstd)
print(vzgapavg,vzgapstd)
print(vzpermavg,vzpermstd)
# Out:
# Vx
# 3.828052113630012e-06 1.210793483211359e-05
# -1.754096791260867e-06 4.13440562053558e-05
# 1.794402881879261e-06 1.6231702407945753e-05
# Vy
# 1.3223442276094763e-07 1.1110432798814964e-05
# 3.601871887867161e-06 4.380817896242429e-05
# -1.0215631345369537e-06 1.5347809183169926e-05
# Vz
# 1.7647447250097154e-06 5.28327976262503e-05
# -6.581218542777109e-07 4.3208563399289356e-05
# 2.775828224343062e-07 2.388540497320421e-05

# %%
resCounts = pd.DataFrame((feedCount,gapCount,permCount),index=('feed','gap','perm'), columns=timesteps)
resCounts.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_res_counts.csv')


countfeeds = np.array(feedCount)
countgaps = np.array(gapCount)
countperms = np.array(permCount)

countfeeds-=countfeeds[0]
countgaps-=countgaps[0]
countperms-=countperms[0]
counttotal=countfeeds+countgaps+countperms

fig,ax = plt.subplots()
x = np.arange(0,len(countfeeds))
ax.plot(x,countfeeds,label='Feed')
ax.plot(x,countgaps,label='Gap')
ax.plot(x,countperms,label='Perm')
ax.plot(x,counttotal,label='Total')
ax.legend()
ax.set_ylabel('Change in number of water molecules in region')
ax.set_xlabel('Timesteps elapsed')
plt.savefig('./plots/pagap'+gap_size+'_nve'+pressure_diff+'_counts.jpg',bbox_inches='tight')

# %%
gapvzSeriesDF.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_vz_gap.csv')
AVGgapvzSeriesDF.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_vz_gap_avg.csv')
gapvzSeriesDF.plot(alpha=0.1, legend=False, ylabel='Velocity of molecules in direction of flow (Å/fs)')
# plt.savefig('./plots/pressure_all_ts.jpg',bbox_inches='tight')
AVGgapvzSeriesDF.plot(yerr='stdev',legend=False, ylabel='Velocity of molecules in direction of flow (Å/fs)')
plt.savefig('./plots/pagap'+gap_size+'_nve'+pressure_diff+'_vz_gap_avg.jpg',bbox_inches='tight')


print(gapvzSeriesDF.mean().mean())
print(gapvzSeriesDF.mean().std())
print(AVGgapvzSeriesDF.mean())
# Out:
# 2.8948917923596414e-05
# 0.00032331569022990076
# mean     0.000167
# stdev    0.000751
# dtype: float64

# %%
gapPressureSeriesDF.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_pressure_gap.csv')
AVGgapPressureSeriesDF.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_pressure_gap_avg.csv')
gapPressureSeriesDF.plot(alpha=0.1, legend=False, ylabel='Pressure of molecules within bin (ATM)')
# plt.savefig('./plots/tube_counts_all_ts.jpg',bbox_inches='tight')
AVGgapPressureSeriesDF.plot(yerr='stdev',legend=False, ylabel='Pressure of molecules within bin (ATM)')
plt.savefig('./plots/pagap'+gap_size+'_nve'+pressure_diff+'_pressure_gap_avg.jpg',bbox_inches='tight')
print(gapPressureSeriesDF.mean().mean())
print(gapPressureSeriesDF.mean().std())
print(AVGgapPressureSeriesDF.mean())
# Out:
# 110.89387705565697
# 1144.9191752976049
# mean     1360.510913
# stdev    3089.047603
# dtype: float64

# %%
gapCountSeriesDF.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_count_gap.csv')
AVGgapCountSeriesDF.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_count_gap_avg.csv')
gapCountSeriesDF.plot(alpha=0.1, legend=False, ylabel='Number of molecules within bin (-)')
# plt.savefig('./plots/tube_counts_all_ts.jpg',bbox_inches='tight')
AVGgapCountSeriesDF.plot(yerr='stdev',legend=False, ylabel='Number of molecules within bin (-)')
plt.savefig('./plots/pagap'+gap_size+'_nve'+pressure_diff+'_count_gap_avg.jpg',bbox_inches='tight')
print(gapCountSeriesDF.mean().mean())
print(gapCountSeriesDF.mean().std())
print(AVGgapCountSeriesDF.mean())
# Out:
# 381.5082864290179
# 14.138639910691776
# mean     347.109480
# stdev      9.435242
# dtype: float64
