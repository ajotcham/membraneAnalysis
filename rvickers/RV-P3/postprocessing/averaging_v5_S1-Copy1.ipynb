# %%
import re
def sorted_alphanumeric(data):
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [ convert(c) for c in re.split('([0-9]+)', key) ] 
    return sorted(data, key=alphanum_key)

# %%
import numpy as np 
import pandas as pd
import os
import gc
import gzip
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
x_min = 0
x_max = 97.7228
y_min = 0
y_max = 166.129
# x_min = 0
# x_max = 119.544
# y_min = 0
# y_max = 138.038
x_len = x_max - x_min
y_len = y_max - y_min


ang3_to_cm3 = (1e8)**3
avo_num = 6.0221409e+23

# Set parent directory containing allsimulations to be analyzed 

gap_size = '20'
pressure_diff = '1000'

parentDir = "../pa_gap/pa_gap"+gap_size+"_nve"+pressure_diff+"/"
allWaterArr = []
# loop over all simulation folders
for simDir in sorted_alphanumeric(os.listdir(parentDir)):
    waterArr = []
    # data is expected to be in a folder titled pressure
    dataDir = parentDir+simDir
    for step in sorted_alphanumeric(os.listdir(dataDir)):
        waterArr.append(dataDir+"/"+step)
    if waterArr:
        allWaterArr.append(waterArr)
    else:
        print("No water array created for: " + dataDir)
print(allWaterArr)
# Out:
# [['../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2540000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2545000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2550000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2555000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2560000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2565000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2570000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2575000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2580000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2585000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2590000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2595000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2600000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2605000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2610000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2615000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2620000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2625000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2630000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2635000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2640000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2645000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2650000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2655000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2660000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2665000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2670000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2675000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2680000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2685000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2690000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2695000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2700000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2705000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2710000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2715000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2720000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2725000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2730000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2735000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2740000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2745000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2750000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2755000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2760000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2765000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2770000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2775000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2780000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2785000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2790000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2795000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2800000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2805000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2810000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2815000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2820000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2825000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2830000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2835000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2840000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2845000.gz', '../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2850000.gz', '../pa_gap/pa_gap20_nve1000/p ...

# %%
i=0
min_atom_positions = []
max_atom_positions = []
# loop through arrays of file names containing data to be analyzed
for waterArr in allWaterArr:
    if i != 0:
        i+=1
        continue  
    timesteps = []
    waterdfs = []
    print(waterArr[0])  
    for waterFile in waterArr:
        print(waterFile)
        with gzip.open(waterFile) as f:
            f.readline().rstrip()
            timestep = f.readline().rstrip().decode("utf-8") 
        timesteps.append(timestep)
        idf = pd.read_csv(waterFile).iloc[7:,:]
        dfCols = idf.iloc[0,].str.split(' ')[0]
        del dfCols[0:2]
        df = idf.iloc[1:,:]['ITEM: TIMESTEP'].str.split(' ', expand=True)
        df.set_axis(dfCols,axis=1,inplace=True)
        df.reset_index(drop=True, inplace=True)
        df = df.apply(pd.to_numeric)
        min_atom_positions.append(df['z'].min())
        max_atom_positions.append(df['z'].max())
#         df = df[df.type.isin([15,16])]
#         df = df[df.vz != 0]
        waterdfs.append(df)
    i+=1
# Out:
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2540000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2540000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2545000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2550000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2555000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2560000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2565000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2570000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2575000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2580000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2585000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2590000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2595000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2600000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2605000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2610000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2615000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2620000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2625000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2630000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2635000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2640000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2645000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2650000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2655000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2660000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2665000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2670000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2675000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2680000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2685000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2690000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2695000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2700000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2705000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2710000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2715000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2720000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2725000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2730000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2735000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2740000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2745000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2750000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2755000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2760000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2765000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2770000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2775000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2780000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2785000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2790000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2795000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2800000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2805000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2810000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2815000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2820000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2825000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2830000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2835000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2840000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2845000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2850000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2855000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2860000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2865000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2870000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2875000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2880000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2885000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2890000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2895000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2900000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2905000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2910000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2915000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2920000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2925000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2930000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2935000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2940000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2945000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2950000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2955000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2960000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2965000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2970000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2975000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2980000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2985000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2990000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.2995000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3000000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3005000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3010000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3015000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3020000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3025000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3030000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3035000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3040000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3045000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3050000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3055000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3060000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3065000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3070000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3075000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3080000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3085000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3090000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3095000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3100000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3105000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3110000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3115000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3120000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3125000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3130000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3135000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3140000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3145000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3150000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3155000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3160000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3165000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3170000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3175000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3180000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3185000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3190000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3195000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3200000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3205000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3210000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3215000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3220000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3225000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3230000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3235000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3240000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3245000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3250000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3255000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3260000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3265000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3270000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3275000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3280000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3285000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3290000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3295000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3300000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3305000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3310000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3315000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3320000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3325000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3330000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3335000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3340000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3345000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3350000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3355000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3360000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3365000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3370000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3375000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3380000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3385000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3390000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3395000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3400000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3405000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3410000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3415000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3420000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3425000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3430000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3435000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3440000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3445000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3450000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3455000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3460000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3465000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3470000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3475000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3480000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3485000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3490000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3495000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3500000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3505000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3510000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3515000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3520000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3525000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3530000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3535000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3540000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3545000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3550000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3555000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3560000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3565000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3570000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3575000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3580000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3585000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3590000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3595000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3600000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3605000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3610000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3615000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3620000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3625000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3630000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3635000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3640000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3645000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3650000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3655000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3660000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3665000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3670000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3675000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3680000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3685000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3690000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3695000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3700000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3705000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3710000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3715000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3720000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3725000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3730000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3735000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3740000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3745000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3750000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3755000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3760000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3765000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3770000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3775000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3780000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3785000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3790000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3795000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3800000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3805000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3810000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3815000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3820000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3825000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3830000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3835000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3840000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3845000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3850000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3855000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3860000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3865000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3870000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3875000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3880000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3885000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3890000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3895000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3900000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3905000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3910000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3915000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3920000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3925000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3930000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3935000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3940000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3945000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3950000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3955000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3960000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3965000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3970000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3975000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3980000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3985000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3990000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.3995000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4000000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4005000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4010000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4015000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4020000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4025000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4030000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4035000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4040000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4045000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4050000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4055000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4060000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4065000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4070000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4075000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4080000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4085000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4090000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4095000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4100000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4105000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4110000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4115000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4120000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4125000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4130000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4135000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4140000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4145000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4150000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4155000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4160000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4165000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4170000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4175000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4180000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4185000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4190000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4195000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4200000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4205000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4210000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4215000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4220000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4225000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4230000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4235000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4240000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4245000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4250000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4255000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4260000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4265000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4270000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4275000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4280000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4285000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4290000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4295000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4300000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4305000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4310000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4315000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4320000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4325000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4330000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4335000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4340000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4345000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4350000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4355000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4360000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4365000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4370000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4375000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4380000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4385000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4390000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4395000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4400000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4405000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4410000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4415000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4420000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4425000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4430000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4435000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4440000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4445000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4450000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4455000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4460000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4465000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4470000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4475000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4480000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4485000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4490000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4495000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4500000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4505000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4510000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4515000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4520000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4525000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4530000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4535000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4540000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4545000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4550000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4555000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4560000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4565000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4570000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4575000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4580000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4585000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4590000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4595000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4600000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4605000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4610000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4615000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4620000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4625000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4630000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4635000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4640000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4645000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4650000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4655000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4660000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4665000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4670000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4675000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4680000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4685000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4690000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4695000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4700000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4705000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4710000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4715000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4720000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4725000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4730000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4735000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4740000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4745000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4750000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4755000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4760000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4765000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4770000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4775000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4780000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4785000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4790000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4795000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4800000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4805000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4810000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4815000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4820000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4825000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4830000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4835000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4840000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4845000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4850000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4855000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4860000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4865000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4870000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4875000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4880000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4885000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4890000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4895000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4900000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4905000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4910000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4915000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4920000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4925000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4930000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4935000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4940000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4945000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4950000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4955000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4960000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4965000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4970000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4975000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4980000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4985000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4990000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.4995000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5000000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5005000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5010000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5015000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5020000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5025000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5030000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5035000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5040000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5045000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5050000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5055000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5060000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5065000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5070000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5075000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5080000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5085000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5090000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5095000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5100000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5105000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5110000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5115000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5120000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5125000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5130000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5135000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5140000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5145000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5150000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5155000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5160000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5165000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5170000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5175000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5180000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5185000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5190000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5195000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5200000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5205000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5210000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5215000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5220000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5225000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5230000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5235000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5240000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5245000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5250000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5255000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5260000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5265000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5270000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5275000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5280000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5285000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5290000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5295000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5300000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5305000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5310000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5315000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5320000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5325000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5330000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5335000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5340000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5345000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5350000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5355000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5360000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5365000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5370000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5375000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5380000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5385000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5390000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5395000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5400000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5405000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5410000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5415000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5420000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5425000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5430000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5435000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5440000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5445000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5450000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5455000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5460000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5465000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5470000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5475000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5480000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5485000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5490000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5495000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5500000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5505000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5510000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5515000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5520000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5525000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5530000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5535000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5540000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5545000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5550000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5555000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5560000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5565000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5570000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5575000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5580000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5585000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5590000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5595000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5600000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5605000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5610000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5615000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5620000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5625000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5630000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5635000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5640000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5645000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5650000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5655000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5660000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5665000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5670000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5675000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5680000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5685000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5690000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5695000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5700000.gz
# ../pa_gap/pa_gap20_nve1000/pressure/pressuredata.5705000.gz

# %%
pressureSeries = []
densitySeries = []
countSeries = []
vxSeries = []
vySeries = []
vzSeries = []

gapPressureSeries = []
gapDensitySeries = []
gapCountSeries = []
gapvxSeries = []
gapvySeries = []
gapvzSeries = []

## gap10
# gap_min = 21
# gap_max = 32

## gap46
gap_min = 60
gap_max = 106

gap_len = gap_max - gap_min
nGapBins = int((gap_len * 0.5) + 1)
gapBinSize = gap_len/nGapBins

z_min = -128.921
z_max = 571.635
z_len = z_max - z_min

nBins = int((z_len * 0.5) + 1)
bin_size = z_len/nBins

min_timestep = 0
max_timestep = 800000000

inlet_z = 105
outlet_z = 280

feedPressures = []
gapPressures = []
permPressures = []

feedCount = []
gapCount = []
permCount = []

feedvxs = []
gapvxs = []
permvxs = []

feedvys = []
gapvys = []
permvys = []

feedvzs = []
gapvzs = []
permvzs = []

i=0
for df in waterdfs:
    if ((int(timesteps[i]) < min_timestep) or (int(timesteps[i]) > max_timestep)):
        i+=1
        continue
    dfMol = pd.DataFrame()

    df['xmass'] = df['mass'] * df['x']
    df['ymass'] = df['mass'] * df['y']
    df['zmass'] = df['mass'] * df['z']
    
    df['vxmass'] = df['mass'] * df['vx']
    df['vymass'] = df['mass'] * df['vy']
    df['vzmass'] = df['mass'] * df['vz']

    # create per molecule dataframe to analyze at finer scale
    # atoms of a molecule are expected to be consecutive

    dfMol['mass'] = df['mass'].groupby(df.index // 3).sum()
    dfMol['xmass'] = df['xmass'].groupby(df.index // 3).sum()
    dfMol['ymass'] = df['ymass'].groupby(df.index // 3).sum()
    dfMol['zmass'] = df['zmass'].groupby(df.index // 3).sum()
    dfMol['vxmass'] = df['vxmass'].groupby(df.index // 3).sum()
    dfMol['vymass'] = df['vymass'].groupby(df.index // 3).sum()
    dfMol['vzmass'] = df['vzmass'].groupby(df.index // 3).sum()
    dfMol['x'] = dfMol['xmass'] / dfMol['mass']
    dfMol['y'] = dfMol['ymass'] / dfMol['mass']
    dfMol['z'] = dfMol['zmass'] / dfMol['mass']
    dfMol['vx'] = dfMol['vxmass'] / dfMol['mass']
    dfMol['vy'] = dfMol['vymass'] / dfMol['mass']
    dfMol['vz'] = dfMol['vzmass'] / dfMol['mass']
    dfMol['stressvol'] = df['v_peratompress'].groupby(df.index // 3).sum()
    dfMol['vol'] = df['c_peratomvol[1]'].groupby(df.index // 3).sum()
    dfMol['press'] = dfMol['stressvol'] / (-3 * dfMol['vol'])
    dfMol['density'] = (dfMol['mass'] / (x_len * y_len * z_len/nBins)) * ang3_to_cm3 / avo_num
    dfMol['pressbin'] = (dfMol['stressvol'] / (-3 * x_len * y_len * z_len/nBins))
    dfMol['bin'] = pd.cut(dfMol['z'], np.linspace(z_min,z_max,nBins),labels=False)*bin_size + (z_min)
    dfMol['ybin'] = pd.cut(dfMol['y'].loc[(dfMol['z'] > inlet_z) & (dfMol['z'] < outlet_z)], np.linspace(gap_min,gap_max,nGapBins), labels=False) * gapBinSize + gap_min
#     stepDF_mean = dfMol.loc[(max_atom_positions[i]-dfMol['z'] > 5) & (dfMol['z']-min_atom_positions[i] > 5)].groupby(['bin'], dropna=True).mean()
#     stepDF_sum = dfMol.loc[(max_atom_positions[i]-dfMol['z'] > 5) & (dfMol['z']-min_atom_positions[i] > 5)].groupby(['bin'], dropna=True).sum()
    stepDF_mean = dfMol.groupby(['bin'], dropna=True).mean()
    stepDF_sum = dfMol.groupby(['bin'], dropna=True).sum()
    stepDF_sum['bin_count'] = dfMol.groupby(['bin'], dropna=True)['bin'].count() 
    gapDF_mean = dfMol.groupby(['ybin'], dropna=True).mean()
    gapDF_sum = dfMol.groupby(['ybin'], dropna=True).sum()
    gapDF_sum['ybin_count'] = dfMol.groupby(['ybin'], dropna=True)['ybin'].count()
    
    feedPressures.append(dfMol['stressvol'].loc[(dfMol['z'] < inlet_z) & (dfMol['z']-min_atom_positions[i] > 5)].sum() / (-3 * dfMol['vol'].loc[(dfMol['z'] < inlet_z) & (dfMol['z']-min_atom_positions[i] > 5)].sum()))
    gapPressures.append(dfMol['stressvol'].loc[(dfMol['z'] < outlet_z) & (dfMol['z'] > inlet_z)].sum() / (-3 * dfMol['vol'].loc[(dfMol['z'] < outlet_z) & (dfMol['z'] > inlet_z)].sum()))
    permPressures.append(dfMol['stressvol'].loc[(dfMol['z'] > outlet_z) & (max_atom_positions[i]-dfMol['z'] > 5)].sum() / (-3 * dfMol['vol'].loc[(dfMol['z'] > outlet_z) & (max_atom_positions[i]-dfMol['z'] > 5)].sum()))
#     feedPressures.append(dfMol['stressvol'].loc[(dfMol['z'] < -50)].sum() / (-3 * x_len * y_len * (-50-min_atom_positions[i])))
#     permPressures.append(dfMol['stressvol'].loc[(dfMol['z'] > 50)].sum() / (-3 * x_len * y_len * (max_atom_positions[i]-50)))
    
    feedCount.append(dfMol['bin'].loc[(dfMol['z'] < inlet_z)].count())
    gapCount.append(dfMol['bin'].loc[(dfMol['z'] < outlet_z) & (dfMol['z'] > inlet_z)].count())
    permCount.append(dfMol['bin'].loc[(dfMol['z'] > outlet_z)].count())
    
    feedvxs.append(dfMol['vx'].loc[(dfMol['z'] < inlet_z) & (dfMol['z']-min_atom_positions[i] > 5)].mean())
    gapvxs.append(dfMol['vx'].loc[(dfMol['z'] < outlet_z) & (dfMol['z'] > inlet_z)].mean())
    permvxs.append(dfMol['vx'].loc[(dfMol['z'] > outlet_z) & (max_atom_positions[i]-dfMol['z'] > 5)].mean())

    feedvys.append(dfMol['vy'].loc[(dfMol['z'] < inlet_z) & (dfMol['z']-min_atom_positions[i] > 5)].mean())
    gapvys.append(dfMol['vy'].loc[(dfMol['z'] < outlet_z) & (dfMol['z'] > inlet_z)].mean())
    permvys.append(dfMol['vy'].loc[(dfMol['z'] > outlet_z) & (max_atom_positions[i]-dfMol['z'] > 5)].mean())

    feedvzs.append(dfMol['vz'].loc[(dfMol['z'] < inlet_z) & (dfMol['z']-min_atom_positions[i] > 5)].mean())
    gapvzs.append(dfMol['vz'].loc[(dfMol['z'] < outlet_z) & (dfMol['z'] > inlet_z)].mean())
    permvzs.append(dfMol['vz'].loc[(dfMol['z'] > outlet_z) & (max_atom_positions[i]-dfMol['z'] > 5)].mean())

    vxSeries.append(stepDF_mean['vx'].rename(timesteps[i], axis=1))
    vySeries.append(stepDF_mean['vy'].rename(timesteps[i], axis=1))
    vzSeries.append(stepDF_mean['vz'].rename(timesteps[i], axis=1))
    
    pressureSeries.append(stepDF_sum['stressvol'].rename(timesteps[i], axis=1)/(-3*stepDF_sum['vol'].rename(timesteps[i], axis=1)))
    densitySeries.append((stepDF_sum['mass'].rename(timesteps[i], axis=1)/(stepDF_sum['vol'].rename(timesteps[i], axis=1)))* ang3_to_cm3 / avo_num)
    countSeries.append(stepDF_sum['bin_count'].rename(timesteps[i], axis=1))
    
    gapCountSeries.append(gapDF_sum['ybin_count'].rename(timesteps[i], axis=1))
    gapPressureSeries.append(gapDF_sum['stressvol'].rename(timesteps[i], axis=1)/(-3*gapDF_sum['vol'].rename(timesteps[i], axis=1)))
    gapDensitySeries.append((gapDF_sum['mass'].rename(timesteps[i], axis=1)/(gapDF_sum['vol'].rename(timesteps[i], axis=1)))* ang3_to_cm3 / avo_num)
    gapvxSeries.append(gapDF_mean['vx'].rename(timesteps[i], axis=1))
    gapvySeries.append(gapDF_mean['vy'].rename(timesteps[i], axis=1))
    gapvzSeries.append(gapDF_mean['vz'].rename(timesteps[i], axis=1))
    i += 1

pressureSeriesDF = pd.concat(pressureSeries, axis=1, ignore_index=False)
densitySeriesDF = pd.concat(densitySeries,axis=1, ignore_index=False)
countSeriesDF = pd.concat(countSeries, axis=1, ignore_index=False)
vxSeriesDF = pd.concat(vxSeries, axis=1, ignore_index=False)
vySeriesDF = pd.concat(vySeries, axis=1, ignore_index=False)                    
vzSeriesDF = pd.concat(vzSeries, axis=1, ignore_index=False)

gapCountSeriesDF = pd.concat(gapCountSeries, axis=1, ignore_index=False)
gapPressureSeriesDF = pd.concat(gapPressureSeries, axis=1, ignore_index=False)
gapDensitySeriesDF = pd.concat(gapDensitySeries,axis=1, ignore_index=False)
gapvxSeriesDF = pd.concat(gapvxSeries, axis=1, ignore_index=False)
gapvySeriesDF = pd.concat(gapvySeries, axis=1, ignore_index=False)                    
gapvzSeriesDF = pd.concat(gapvzSeries, axis=1, ignore_index=False)
                       
                       
AVGpressureSeriesDF = pd.DataFrame()
AVGdensitySeriesDF = pd.DataFrame()
AVGvxSeriesDF = pd.DataFrame()
AVGvySeriesDF = pd.DataFrame()
AVGvzSeriesDF = pd.DataFrame()
AVGcountSeriesDF = pd.DataFrame()

AVGgapPressureSeriesDF = pd.DataFrame()
AVGgapDensitySeriesDF = pd.DataFrame()
AVGgapCountSeriesDF = pd.DataFrame()

AVGgapvxSeriesDF = pd.DataFrame()
AVGgapvySeriesDF = pd.DataFrame()
AVGgapvzSeriesDF = pd.DataFrame()            

AVGpressureSeriesDF['mean'] = pressureSeriesDF.mean(axis=1)
AVGpressureSeriesDF['stdev'] = pressureSeriesDF.std(axis=1)

AVGdensitySeriesDF['mean'] = densitySeriesDF.mean(axis=1)
AVGdensitySeriesDF['stdev'] = densitySeriesDF.std(axis=1)

AVGcountSeriesDF['mean'] = countSeriesDF.mean(axis=1)
AVGcountSeriesDF['stdev'] = countSeriesDF.std(axis=1)

AVGvxSeriesDF['mean'] = vxSeriesDF.mean(axis=1)
AVGvxSeriesDF['stdev'] = vxSeriesDF.std(axis=1)
AVGvySeriesDF['mean'] = vySeriesDF.mean(axis=1)
AVGvySeriesDF['stdev'] = vySeriesDF.std(axis=1)
AVGvzSeriesDF['mean'] = vzSeriesDF.mean(axis=1)
AVGvzSeriesDF['stdev'] = vzSeriesDF.std(axis=1)
                       
AVGgapCountSeriesDF['mean'] = gapCountSeriesDF.mean(axis=1)
AVGgapCountSeriesDF['stdev'] = gapCountSeriesDF.std(axis=1)
AVGgapPressureSeriesDF['mean'] = gapPressureSeriesDF.mean(axis=1)
AVGgapPressureSeriesDF['stdev'] = gapPressureSeriesDF.std(axis=1)
AVGgapDensitySeriesDF['mean'] = gapDensitySeriesDF.mean(axis=1)
AVGgapDensitySeriesDF['stdev'] = gapDensitySeriesDF.std(axis=1)
                       
AVGgapvxSeriesDF['mean'] = gapvxSeriesDF.mean(axis=1)
AVGgapvxSeriesDF['stdev'] = gapvxSeriesDF.std(axis=1)
AVGgapvySeriesDF['mean'] = gapvySeriesDF.mean(axis=1)
AVGgapvySeriesDF['stdev'] = gapvySeriesDF.std(axis=1)
AVGgapvzSeriesDF['mean'] = gapvzSeriesDF.mean(axis=1)
AVGgapvzSeriesDF['stdev'] = gapvzSeriesDF.std(axis=1)

pressureSeriesDF.index.names = ['Distance in z (Å)']
AVGpressureSeriesDF.index.names = ['Distance in z (Å)']

densitySeriesDF.index.names = ['Distance in z (Å)']
AVGdensitySeriesDF.index.names = ['Distance in z (Å)']
                       
vxSeriesDF.index.names = ['Distance in z (Å)']
AVGvxSeriesDF.index.names = ['Distance in z (Å)']                      
vySeriesDF.index.names = ['Distance in z (Å)']
AVGvySeriesDF.index.names = ['Distance in z (Å)']        
vzSeriesDF.index.names = ['Distance in z (Å)']
AVGvzSeriesDF.index.names = ['Distance in z (Å)']                      

gapCountSeriesDF.index.names = ['Distance in y (Å)']
AVGgapCountSeriesDF.index.names = ['Distance in y (Å)']
gapPressureSeriesDF.index.names = ['Distance in y (Å)']
AVGgapPressureSeriesDF.index.names = ['Distance in y (Å)']
gapDensitySeriesDF.index.names = ['Distance in y (Å)']
AVGgapDensitySeriesDF.index.names = ['Distance in y (Å)']

gapvxSeriesDF.index.names = ['Distance in y (Å)']
AVGgapvxSeriesDF.index.names = ['Distance in y (Å)']     
gapvySeriesDF.index.names = ['Distance in y (Å)']
AVGgapvySeriesDF.index.names = ['Distance in y (Å)']    
gapvzSeriesDF.index.names = ['Distance in y (Å)']
AVGgapvzSeriesDF.index.names = ['Distance in y (Å)']

# %%
pressureSeriesDF.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_pressure.csv')
AVGpressureSeriesDF.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_pressure_avg.csv')
pressureSeriesDF.plot(alpha=0.1, legend=False, ylabel='Pressure of molecules within bin (ATM)')
# plt.savefig('./plots/pressure_all_ts.jpg',bbox_inches='tight')
AVGpressureSeriesDF.plot(yerr='stdev',legend=False, ylabel='Pressure of molecules within bin (ATM)', ylim = (-1500,2500))
plt.savefig('./plots/pagap'+gap_size+'_nve'+pressure_diff+'_pressure_avg.jpg',bbox_inches='tight')


print(pressureSeriesDF.mean().mean())
print(pressureSeriesDF.mean().std())
print(AVGpressureSeriesDF.mean())
# Out:
# 570.5316920809615
# 62.33444204953689
# mean     596.432626
# stdev    690.760590
# dtype: float64

# %%
densitySeriesDF.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_density.csv')
AVGdensitySeriesDF.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_density_avg.csv')
densitySeriesDF.plot(alpha=0.1, legend=False, ylabel='Density of molecules within bin (g/cm$^3$)')
# plt.savefig('./plots/pressure_all_ts.jpg',bbox_inches='tight')
AVGdensitySeriesDF.plot(yerr='stdev',legend=False, ylabel='Density of molecules within bin (g/cm$^3$)')
plt.savefig('./plots/pagap'+gap_size+'_nve'+pressure_diff+'_density_avg.jpg',bbox_inches='tight')


print(densitySeriesDF.mean().mean())
print(densitySeriesDF.mean().std())
print(AVGdensitySeriesDF.mean())
# Out:
# 1.0106480379040763
# 0.001283941187697199
# mean     1.003186
# stdev    0.012142
# dtype: float64

# %%
vzSeriesDF.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_vz.csv')
AVGvzSeriesDF.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_vz_avg.csv')
vzSeriesDF.plot(alpha=0.1, legend=False, ylabel='Velocity of molecules in direction of flow (Å/fs)')
# plt.savefig('./plots/pressure_all_ts.jpg',bbox_inches='tight')
AVGvzSeriesDF.plot(yerr='stdev',legend=False, ylabel='Velocity of molecules in direction of flow (Å/fs)')
plt.savefig('./plots/pagap'+gap_size+'_nve'+pressure_diff+'_vz_avg.jpg',bbox_inches='tight')


print(vzSeriesDF.mean().mean())
print(vzSeriesDF.mean().std())
print(AVGvzSeriesDF.mean())
# Out:
# 5.443714062605848e-06
# 1.6826684260265143e-05
# mean     0.000006
# stdev    0.000220
# dtype: float64

# %%
resPressures = pd.DataFrame((feedPressures,gapPressures,permPressures),index=('feed','gap','perm'), columns=timesteps)
resPressures.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_res_pressures.csv')
pfeeds = np.array(feedPressures)
pgaps = np.array(gapPressures)
pperms = np.array(permPressures)

pfeedavg = np.mean(pfeeds)
pfeedstd = np.std(pfeeds)
pgapavg = np.mean(pgaps)
pgapstd = np.std(pgaps)
ppermavg = np.mean(pperms)
ppermstd = np.std(pperms)

print("feed")
print(pfeedavg,pfeedstd)
print("gap")
print(pgapavg,pgapstd)
print("perm")
print(ppermavg,ppermstd)
# Out:
# feed
# 1068.1330641335874 67.82307147870861
# gap
# 462.29518989815585 128.39179725653295
# perm
# 68.8054209772115 53.999731089009465

# %%
resVelocities = pd.DataFrame((feedvxs,gapvxs,permvxs,feedvys,gapvys,permvys,feedvzs,gapvzs,permvzs),index=('feedvx','gapvx','permvx','feedvy','gapvy','permvy','feedvz','gapvz','permvz'),columns=timesteps)
resVelocities.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_res_velocties.csv')

vxfeeds = np.array(feedvxs)
vxgaps = np.array(gapvxs)
vxperms = np.array(permvxs)

vxfeedavg = np.mean(vxfeeds)
vxfeedstd = np.std(vxfeeds)
vxgapavg = np.mean(vxgaps)
vxgapstd = np.std(vxgaps)
vxpermavg = np.mean(vxperms)
vxpermstd = np.std(vxperms)

vyfeeds = np.array(feedvys)
vygaps = np.array(gapvys)
vyperms = np.array(permvys)

vyfeedavg = np.mean(vyfeeds)
vyfeedstd = np.std(vyfeeds)
vygapavg = np.mean(vygaps)
vygapstd = np.std(vygaps)
vypermavg = np.mean(vyperms)
vypermstd = np.std(vyperms)

vzfeeds = np.array(feedvzs)
vzgaps = np.array(gapvzs)
vzperms = np.array(permvzs)

vzfeedavg = np.mean(vzfeeds)
vzfeedstd = np.std(vzfeeds)
vzgapavg = np.mean(vzgaps)
vzgapstd = np.std(vzgaps)
vzpermavg = np.mean(vzperms)
vzpermstd = np.std(vzperms)

print("Vx")
print(vxfeedavg,vxfeedstd)
print(vxgapavg,vxgapstd)
print(vxpermavg,vxpermstd)

print("Vy")
print(vyfeedavg,vyfeedstd)
print(vygapavg,vygapstd)
print(vypermavg,vypermstd)

print("Vz")
print(vzfeedavg,vzfeedstd)
print(vzgapavg,vzgapstd)
print(vzpermavg,vzpermstd)
# Out:
# Vx
# 2.4537590949345585e-07 1.3151537996470729e-05
# -1.6815296849219035e-06 3.230970834225896e-05
# 2.1249971687971883e-06 1.5087303344339574e-05
# Vy
# -2.554595424451776e-07 1.1787857901757608e-05
# 1.6010349211867673e-07 3.2275150337476075e-05
# -5.095711743921026e-07 1.5139353231114297e-05
# Vz
# 2.4272962285017475e-06 2.207725420478617e-05
# 1.0879169717162221e-05 3.133487957280985e-05
# 2.289252628038931e-06 1.8150294353993502e-05

# %%
resCounts = pd.DataFrame((feedCount,gapCount,permCount),index=('feed','gap','perm'), columns=timesteps)
resCounts.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_res_counts.csv')


countfeeds = np.array(feedCount)
countgaps = np.array(gapCount)
countperms = np.array(permCount)

countfeeds-=countfeeds[0]
countgaps-=countgaps[0]
countperms-=countperms[0]
counttotal=countfeeds+countgaps+countperms

fig,ax = plt.subplots()
x = np.arange(0,len(countfeeds))
ax.plot(x,countfeeds,label='Feed')
ax.plot(x,countgaps,label='Gap')
ax.plot(x,countperms,label='Perm')
ax.plot(x,counttotal,label='Total')
ax.legend()
ax.set_ylabel('Change in number of water molecules in region')
ax.set_xlabel('Timesteps elapsed')
plt.savefig('./plots/pagap'+gap_size+'_nve'+pressure_diff+'_counts.jpg',bbox_inches='tight')

# %%
gapvzSeriesDF.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_vz_gap.csv')
AVGgapvzSeriesDF.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_vz_gap_avg.csv')
gapvzSeriesDF.plot(alpha=0.1, legend=False, ylabel='Velocity of molecules in direction of flow (Å/fs)')
# plt.savefig('./plots/pressure_all_ts.jpg',bbox_inches='tight')
AVGgapvzSeriesDF.plot(yerr='stdev',legend=False, ylabel='Velocity of molecules in direction of flow (Å/fs)')
plt.savefig('./plots/pagap'+gap_size+'_nve'+pressure_diff+'_vz_gap_avg.jpg',bbox_inches='tight')


print(gapvzSeriesDF.mean().mean())
print(gapvzSeriesDF.mean().std())
print(AVGgapvzSeriesDF.mean())
# Out:
# 1.32350339207243e-05
# 0.0001888179415879563
# mean     0.000012
# stdev    0.000482
# dtype: float64

# %%
gapPressureSeriesDF.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_pressure_gap.csv')
AVGgapPressureSeriesDF.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_pressure_gap_avg.csv')
gapPressureSeriesDF.plot(alpha=0.1, legend=False, ylabel='Pressure of molecules within bin (ATM)')
# plt.savefig('./plots/tube_counts_all_ts.jpg',bbox_inches='tight')
AVGgapPressureSeriesDF.plot(yerr='stdev',legend=False, ylabel='Pressure of molecules within bin (ATM)')
plt.savefig('./plots/pagap'+gap_size+'_nve'+pressure_diff+'_pressure_gap_avg.jpg',bbox_inches='tight')
print(gapPressureSeriesDF.mean().mean())
print(gapPressureSeriesDF.mean().std())
print(AVGgapPressureSeriesDF.mean())
# Out:
# 595.223572512633
# 487.76537680217194
# mean      647.916236
# stdev    1261.690985
# dtype: float64

# %%
gapCountSeriesDF.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_count_gap.csv')
AVGgapCountSeriesDF.to_csv('./csv/pagap'+gap_size+'_nve'+pressure_diff+'_count_gap_avg.csv')
gapCountSeriesDF.plot(alpha=0.1, legend=False, ylabel='Number of molecules within bin (-)')
# plt.savefig('./plots/tube_counts_all_ts.jpg',bbox_inches='tight')
AVGgapCountSeriesDF.plot(yerr='stdev',legend=False, ylabel='Number of molecules within bin (-)')
plt.savefig('./plots/pagap'+gap_size+'_nve'+pressure_diff+'_count_gap_avg.jpg',bbox_inches='tight')
print(gapCountSeriesDF.mean().mean())
print(gapCountSeriesDF.mean().std())
print(AVGgapCountSeriesDF.mean())
# Out:
# 712.9999400446433
# 18.77135620691829
# mean     698.998230
# stdev     12.167027
# dtype: float64
